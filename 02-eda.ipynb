# %% [markdown]
# # 02 - Exploratory data analysis

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

SEED=42
np.random.seed(SEED)

# %%
# load data
df = pd.read_csv("./data/processed/german.csv")

y = df["credit_risk"]
X = df.drop(columns=["credit_risk", "id"])

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=SEED, stratify=y
)

# %% [markdown]
# We check for data imbalance. We find that there is not one, so we can use accuracy as our model refitting metric.

# %%
# check for data imbalance? 
print(y_train.value_counts())   # 560/240
print(y_test.value_counts())    # 140/60

# we find that our data is not imbalanced so we can use accuracy as a metric
